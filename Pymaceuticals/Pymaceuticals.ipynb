# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

df1 = pd.read_csv(mouse_drug_data_to_load)
df2 = pd.read_csv(clinical_trial_data_to_load)
combineddf = pd.merge(df1, df2, on="Mouse ID")

df = pd.DataFrame(combineddf)
df.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
group_drug_time = df.groupby(['Drug', 'Timepoint'])
tumor_mean = group_drug_time['Tumor Volume (mm3)'].mean()
tumor_df = pd.DataFrame(tumor_mean)
tumor_df
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325
# ...                                 ...
# Zoniferol 25                  55.432935
#           30                  57.713531
#           35                  60.089372
#           40                  62.916692
#           45                  65.960888
#
# [100 rows x 1 columns]

# %%
drug_time_error = group_drug_time['Tumor Volume (mm3)'].sem()
std_err_drugs = pd.DataFrame(drug_time_error)
std_err_drugs
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                    0.000000
#           5                    0.448593
#           10                   0.702684
#           15                   0.838617
#           20                   0.909731
# ...                                 ...
# Zoniferol 25                   0.602513
#           30                   0.800043
#           35                   0.881426
#           40                   0.998515
#           45                   1.003576
#
# [100 rows x 1 columns]

# %%
tumormunge = tumor_df.reset_index()
tumor_pivot = pd.pivot_table(tumormunge, index=['Timepoint'], columns = ['Drug'])
tumor_pivot
# Out:
#           Tumor Volume (mm3)                                              \
# Drug               Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol
# Timepoint
# 0                  45.000000  45.000000  45.000000  45.000000  45.000000
# 5                  44.266086  46.503051  47.062001  47.389175  46.796098
# 10                 43.084291  48.285125  49.403909  49.582269  48.694210
# 15                 42.064317  50.094055  51.296397  52.399974  50.933018
# 20                 40.716325  52.157049  53.197691  54.920935  53.644087
# 25                 39.939528  54.287674  55.715252  57.678982  56.731968
# 30                 38.769339  56.769517  58.299397  60.994507  59.559509
# 35                 37.816839  58.827548  60.742461  63.371686  62.685087
# 40                 36.958001  61.467895  63.162824  66.068580  65.600754
# 45                 36.236114  64.132421  65.755562  70.662958  69.265506
#
#
# Drug         Placebo   Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000
# 5          47.125589  47.248967  43.944859  47.527452  46.851818
# 10         49.423329  49.101541  42.531957  49.463844  48.689881
# 15         51.359742  51.067318  41.495061  51.529409  50.779059
# 20         54.364417  53.346737  40.238325  54.067395  53.170334
# 25         57.482574  55.504138  38.974300  56.166123  55.432935
# 30         59.809063  58.196374  38.703137  59.826738  57.713531
# 35         62.420615  60.350199  37.451996  62.440699  60.089372
# 40         65.052675  63.045537  36.574081  65.356386  62.916692
# 45         68.084082  66.258529  34.955595  68.438310  65.960888

# %%
# # Generate the Plot (with Error Bars)
tumor_capo = tumor_pivot['Tumor Volume (mm3)']['Capomulin']
tumor_ceft = tumor_pivot['Tumor Volume (mm3)']['Ceftamin']
tumor_inf = tumor_pivot['Tumor Volume (mm3)']['Infubinol']
tumor_keta = tumor_pivot['Tumor Volume (mm3)']['Ketapril']
tumor_x = [0,5,10,15,20,25,30,35,40,45]

tum_plt_1 = plt.scatter(tumor_x, tumor_capo, label="Capomulin")
tum_plt_2 = plt.scatter(tumor_x, tumor_ceft, label ="Ceftamin")
tum_plt_3 = plt.scatter(tumor_x, tumor_inf, label ="Infubinol")
tum_plt_4 = plt.scatter(tumor_x, tumor_keta, label="Ketapril")
plt.legend(loc="best", fontsize="small", fancybox=True)
# # Save the Figure
plt.savefig("Output/tum_plt.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-43d4467afe69> in <module>
#      12 plt.legend(loc="best", fontsize="small", fancybox=True)
#      13 # # Save the Figure
# ---> 14 plt.savefig("Output/tum_plt.png")
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     720 def savefig(*args, **kwargs):
#     721     fig = gcf()
# --> 722     res = fig.savefig(*args, **kwargs)
#     723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2080                     orientation=orientation,
#    2081                     bbox_inches_restore=_bbox_inches_restore,
# -> 2082                     **kwargs)
#    2083             finally:
#    2084                 if bbox_inches and restore_bbox:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
#     532                                self.figure.dpi, metadata=metadata)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     445 def open_file_cm(path_or_file, mode="r", encoding=None):
#     446     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 447     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     448     if opened:
#     449         with fh:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     430             fh = bz2.BZ2File(fname, flag)
#     431         else:
# --> 432             fh = open(fname, flag, encoding=encoding)
#     433         opened = True
#     434     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Output/tum_plt.png'

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
met_mean = group_drug_time['Metastatic Sites'].mean()
met_df = pd.DataFrame(met_mean)
met_df

# %%
std_err_mets = group_drug_time['Metastatic Sites'].sem()
met_err_df = pd.DataFrame(std_err_mets)
met_err_df

# %%
met_pivot = pd.pivot_table(met_df, index=['Timepoint'], columns = ['Drug'])
met_pivot

# %%
# Generate the Plot (with Error Bars)
met_var = met_df.reset_index()
met_x = met_var['Metastatic Sites']
met_y = met_var['Timepoint']
met_plt = plt.scatter(met_x, met_y, met_err_df)
plt.legend(loc="best", fontsize="small", fancybox=True)

# Save the Figure

# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
mouse_count = group_drug_time['Mouse ID'].nunique()
mouse_df = pd.DataFrame(mouse_count)
mouse_df

# %%
mouse_pivot = pd.pivot_table(mouse_df, index=['Timepoint'], columns = ['Drug'])
mouse_pivot

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
